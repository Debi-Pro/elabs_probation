# %% [markdown]
# # EXPLORATORY DATA ANALYSIS (EDA) ON GLOBAL SUPERSTORE DATASET

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\KIIT0001\OneDrive\Desktop\New fcloud dataoclder (2)\Documents\WPS Cloud Files\521970258\Roaming Document\Global_Superstore2.xlsx")

# %%
df.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %% [markdown]
# ## SALES BY REGION

# %%
region_sales = df.groupby("Region")["Sales"].sum().sort_values(ascending=False)

plt.figure(figsize=(8,5))
sns.barplot(x=region_sales.index, y=region_sales.values, palette="viridis")
plt.title("Total Sales by Region")
plt.ylabel("Sales")
plt.xlabel("Region")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_24136\2682799249.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=region_sales.index, y=region_sales.values, palette="viridis")

# %% [markdown]
# ## SALES VS PROFIT BY CATEGORY

# %%
plt.figure(figsize=(8,5))
sns.barplot(x="Category", y="Sales", data=df, ci=None, color="skyblue", label="Sales")
sns.barplot(x="Category", y="Profit", data=df, ci=None, color="orange", label="Profit")
plt.title("Sales vs Profit by Category")
plt.legend()
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_24136\2810584653.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Category", y="Sales", data=df, ci=None, color="skyblue", label="Sales")
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_24136\2810584653.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Category", y="Profit", data=df, ci=None, color="orange", label="Profit")

# %% [markdown]
# # TOP 10 SUB-CATEGORIES BY SALES

# %%
sub_sales = df.groupby("Sub-Category")["Sales"].sum().nlargest(10)

plt.figure(figsize=(10,5))
sns.barplot(x=sub_sales.values, y=sub_sales.index, palette="mako")
plt.title("Top 10 Sub-Categories by Sales")
plt.xlabel("Sales")
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_24136\937789952.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sub_sales.values, y=sub_sales.index, palette="mako")

# %% [markdown]
# # PROFIT DISTRIBUTION

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Profit"], bins=50, kde=True, color="green")
plt.title("Distribution of Profit")
plt.xlabel("Profit")
plt.show()

# %% [markdown]
# # SALES BY SHIP MODE

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x="Ship Mode", y="Sales",data=df, palette="Set2")
plt.title("Sales Distribution by Ship Mode")
plt.show()
# Out:
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_24136\2841727790.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Ship Mode", y="Sales",data=df, palette="Set2")

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# - **From the above analysis, we can conclude:**
#
# - **Region:** Some regions (like US or APAC) contribute significantly more to sales.
# - **Category:** Technology and Office Supplies may have higher profits compared to Furniture.
# - **Top Sub-Categories:** Certain sub-categories dominate revenue (like Phones, Chairs, or Copiers).
# - **Profit Distribution:** Profit values are skewed, with many small profits/losses and a few very high profits.
# - **Shipping Mode:** Sales behavior varies with shipping mode, e.g., Standard Class vs. Same Day.
#
# **This helps us understand overall performance and identify focus areas for the business.**
